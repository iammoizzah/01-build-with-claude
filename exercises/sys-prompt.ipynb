# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None):

    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
        system=system
    )
    return message.content[0].text

# %%
from anthropic import Anthropic


client = Anthropic()
model = "claude-haiku-4-5"

# %%
messages = []
add_user_message(
    messages,
    "write a python function that checks the string for duplicate characters"
)

answer = chat(
    messages, system="you are a python engineer who writes very concise code")

answer
# Out:
# '```python\ndef has_duplicates(s):\n    return len(s) != len(set(s))\n```\n\nOr if you need to find which characters are duplicated:\n\n```python\ndef find_duplicates(s):\n    return [c for c in set(s) if s.count(c) > 1]\n```\n\nOr with a single pass (more efficient for large strings):\n\n```python\ndef find_duplicates(s):\n    seen, dupes = set(), set()\n    for c in s:\n        if c in seen:\n            dupes.add(c)\n        seen.add(c)\n    return list(dupes)\n```\n\n**Usage:**\n```python\nhas_duplicates("hello")      # True (l appears twice)\nhas_duplicates("world")      # False\nfind_duplicates("hello")     # [\'l\']\nfind_duplicates("aabbcc")    # [\'a\', \'b\', \'c\']\n```'
